# %% [markdown]
# The code is by Anastasia Opara (www.anastasiaopara.com)
#
# Based on "Image Quilting for Texture Synthesis and Transfer" and "Real-Time Texture Synthesis by Patch-Based Sampling" papers

# %%
from makeGif import *
from patchBasedTextureSynthesis import *

# %% [markdown]
# ### This part requires your input! :)
# ##### So, what are all those parameters anyway? Glad you asked!
# * **exampleMapPath** - a string with a path to the example image that you want to generate more of!
#
# * **outputSize** - a path where you want your output image(s) to be saved to! (the algorithm will also create a txt file with your parameters, so you don't forget the setting you used for different images ^^)
#
# * **PatchSize** - how big are the patches that will be copied into the generated image
#
# * **OverlapSize** - the width of a border around the patch via which we perform the search (borders colors have to match)
#
# * **windowStep** - to reduce the amount of self-similar patches, when sampling from the example map, we can ask to only check for patches with a X offset step (that is basically our 'sliding' window step :))
#
# * **snapshots** - will save an image per iteration (if False, only save the final image) - needed if you want to make a gif :)
#
# * **mirror_hor and mirror_vert** - whether you want the example patches to be mirror veritcally or horizontally
#
# And...that's all! Have fun :)

# %%
#PARAMS
exampleMapPath = "imgs/1.jpg"
outputPath = "out/1/"
patchSize = 50 #size of the patch (without the overlap)
overlapSize = 10 #the width of the overlap region
outputSize = [300,300]

pbts = patchBasedTextureSynthesis(exampleMapPath, outputPath, outputSize, patchSize, overlapSize, in_windowStep = 5, in_mirror_hor = True, in_mirror_vert = True, in_shapshots = True)
pbts.resolveAll()
# Out:
# None

# %% [markdown]
# ## *Make GIF!*
# If you chose 'snapshots = True' option, then you can convert the sequence of images into an animated GIF!
# * **frame_every_X_steps** - sometimes you want your GIF to not include *every* frame, this one allows you to skip X number of frames! (don't worry, it will always end up on the last frame to show the fully resolved image)
# * **repeat_ending** - specify how many frames the GIF will loop over the final resolved image

# %%
gifOutputPath = "out/outGif.gif"

makeGif(outputPath, gifOutputPath, frame_every_X_steps = 1, repeat_ending = 5)
